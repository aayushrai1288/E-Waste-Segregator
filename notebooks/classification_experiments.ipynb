# %% [markdown]
# # E-Waste Classification Research: ResNet-50 vs VGG16
#
# ## 1. Abstract
# This notebook explores the classification of electronic waste into 10 distinct categories. We compare two popular architectures: ResNet-50 and VGG16, analyzing their performance, convergence rates, and error patterns.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import time
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
# Understanding the dataset distribution and visual characteristics.

# %%
data_dir = '../data/processed'
classes = os.listdir(os.path.join(data_dir, 'train'))
print(f"Found {len(classes)} classes: {classes}")

# Class distribution
counts = {c: len(os.listdir(os.path.join(data_dir, 'train', c))) for c in classes}
plt.figure(figsize=(12, 6))
sns.barplot(x=list(counts.keys()), y=list(counts.values()))
plt.title('Training Class Distribution')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Visualizing Samples

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

dataset = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
]))
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)
inputs, classes_idx = next(iter(dataloader))
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[classes[x] for x in classes_idx])

# %% [markdown]
# ## 3. Training Strategy
# We use transfer learning with pre-trained weights from ImageNet. The final layer is replaced to match our 10 classes.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}

    for epoch in range(num_epochs):
        # ... (Training loop logic) ...
        pass # Implementation in src/train.py

    return model, history

# %% [markdown]
# ## 4. Evaluation and Metrics
# Post-training analysis using Confusion Matrix and F1-Score.

# %%
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
